# %% [markdown]
# ### Домашнее задание 8

# %% [markdown]
# ### Задача 1
#
# Самостоятельно реализуйте на питоне двусвязный список.
#
# - создайте класс Double_linked_list
# - реализуйте итеративную распечатку (в прямом и обратном порядке)
# - реализуйте изменение значения k-го элемента
# - реализуйте добавление элемента в середину списка (на k-е место)
# - реализуйте "сжатие" листа: 1-2-3-3-3-3-5-5-5-4-3-3-3-3-3-2 превращается в 1-2-3-5-4-3-2

# %% [markdown]
# ### Задача 2
#
# Реализуйте обнаружение цикла в односвязном списке. Протестируйте свой метод.
