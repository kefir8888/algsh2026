# %% [markdown]
# ### Домашнее задание 7: практическая часть

# %% [markdown]
# ### Задача 1
#
# Реализуйте структуру данных Стек на Python. Создайте класс Stack с функциями
# - push
# - pop
# - length
# - empty
# - is_empty
#
# Протестируйте весь функционал своей структуры данных.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 2
#
# Постройте алгоритм, проверяющий, что строка является правильным скобочным выражением. Пример правильного: "(())()". Пример неправильного: "())(()"
#
# Протестируйте алгоритм на нескольких примерах.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 3
#
# Majority element в массиве из $n$ элементов - это элемент, встречающийся не менее $\frac{n}{2}$ раз.
# Реализуйте поиск majority element в массиве с использованием
# - $O(n)$ дополнительной памяти
# - $O(1)$ дополнительной памяти

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 4
#
# На занятии была начата реализация односвязного списка. Продолжите её, добавив рекурсивную функцию изменения k-го элемента списка. Это можно сделать в рамках того же класса Node. Создайте функцию, которая будет вызывать себя же, но у своего next, и менять значение элемента, если до него дошла. Также реализуйте функцию рекурсивной распечатки односязного списка.

# %%
# YOUR CODE HERE
