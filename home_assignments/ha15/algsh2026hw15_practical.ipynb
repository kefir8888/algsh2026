# %% [markdown]
# ## Домашнее задание 15

# %% [markdown]
# ### Задача 1
#
# Дополните решение задачи о рюкзаке и научитесь находить не только максимальную достижимую стоимость, но и оптимальный набор предметов

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 2
#
# Реализуйте задачу 5 из теоретической домашки:
#
# На вход задачи подаются положительные целые числа $n$, $a_1, \dots, a_n$, и $t$. Необходимо проверить, представимо ли число $t$ в виде суммы из некоторых членов последовательности $a_1, \dots, a_n$. Каждое число разрешено использовать не более одного раза, можно не использовать вовсе. Постройте алгоритм со временем работы $O(nt)$

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 3
#
# Реализуйте (самостоятельно!) алгоритм поиска расстояния редактирования для двух строк (расстояние Левенштейна). Читать вики и учебники можно, гуглить код нельзя. Посмотреть видос на ютубе можно, пользоваться нейросетями нельзя.

# %%
# YOUR CODE HERE
