# %% [markdown]
# ## Домашнее задание 12
#
# При решении задания можно пользоваться записями лекций, заметками, чатом курса, чатом с преподавателем, википедией, литературой, гуглом. Нельзя пользоваться нейросетями и чужими домашками, это лишает задание смысла.

# %% [markdown]
# ### Задача 1
#
# Реализуйте обход в ширину (BFS). Визуализируйте все шаги с помощью networkx.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 2
#
# Реализуйте топологическую сортировку. Визуализируйте все шаги с помощью networkx.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 3
#
# Реализуйте поиск сильно связных компонент и построение метаграфа. Визуализируйте все шаги с помощью networkx.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 4
#
# Реализуйте алгоритм, находящий кратчайшее решение Ivy Cube. Код, который мы обсуждали на занятии, лежит в папке лекции.

# %%
# YOUR CODE HERE
