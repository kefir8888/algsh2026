# %% [markdown]
# ## Домашнее задание 16

# %% [markdown]
# ### Задача 1
#
# Реализуйте алгоритм поиска максимальной по длине возрастающей подпоследовательности массива с асимптотикой $O(n \log n)$. Можно гуглить алгоритмы, смотреть видосы (например https://youtu.be/22s1xxRvy28), советоваться с друзьями, а вот пользоваться нейросетями или просто копипастить код не стоит.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 2
#
# Модифицируйте алгоритм быстрой сортировки с семинара так, чтобы в качестве опорного элемента использовалась медиана массива.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 3
#
# Модифицируйте реализацию дерева отрезков с семинара для нахождения среднего значения элементов в непрерывном подмассиве.

# %%
# YOUR CODE HERE
