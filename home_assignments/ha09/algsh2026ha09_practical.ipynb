# %% [markdown]
# ## Домашнее задание 9
#
# При решении задания можно пользоваться записями лекций, заметками, чатом курса, чатом с преподавателем, википедией, литературой, гуглом. Нельзя пользоваться нейросетями и чужими домашками, это лишает задание смысла.

# %% [markdown]
# ### Задача 1
#
# Реализуйте решение диофантовых уравнений на основе расширенного алгоритма Евклида, который был написан на занятии (учитывая в том числе и случай, когда решений нет).
#
# Реализуйте поиск обратного остатка по модулю на основе решения диофантовых уравнений.

# %%
### YOUR CODE HERE

# %% [markdown]
# ### Задача 2
#
# Обобщите интегральные массивы на двумерный случай. Можно воспользоваться массивами из numpy, если хочется. Сравните производительность прямого подсчета суммы в подмассиве и подсчета с помощью интегральных массивов.

# %%
### YOUR CODE HERE

# %% [markdown]
# ### Задача 3
#
# Доделайте pretty_print из семинарского кода так, чтобы рисование нижнего слоя в дереве происходило правильно. Листья должны висеть под своими родителями.

# %%
### YOUR CODE HERE
