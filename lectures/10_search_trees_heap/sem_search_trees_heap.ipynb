# %%
#search in tree
#deleting from tree

# %%
import numpy as np

class Node:
    def __init__(self, key, val = None):
        self.key = key
        self.val = val
        self.l = None
        self.r = None
    
    def set_l(self, new_l):
        self.l = new_l

    def set_r(self, new_r):
        self.r = new_r
    
    def print(self):
        if (self.l is not None):
            self.l.print()

        print(f"{self.key} : {self.val}; ", end="")

        if (self.r is not None):
            self.r.print()
    
    def pretty_print(self, depth, max_depth, strings):
        if (self.l is not None):
            self.l.pretty_print(depth + 1, max_depth, strings)
        
        else:
            strings[depth + 1] += " " * 2**(max_depth - depth - 1)

        strings[depth] += " " * (2**(max_depth - depth - 1) - 1) + str(self.key) + " " * (2**(max_depth - depth - 1))

        if (self.r is not None):
            self.r.pretty_print(depth + 1, max_depth, strings)

        else:
            strings[depth + 1] += " " * 2**(max_depth - depth - 1)
    
    def add_element(self, key, val):
        if (key == self.key):
            print(f"key {key} already in tree; ignoring")
            return
        
        if (key < self.key):
            if (self.l is not None):
                self.l.add_element(key, val)
            
            else:
                self.l = Node(key, val)
        
        else:
            if (self.r is not None):
                self.r.add_element(key, val)
            
            else:
                self.r = Node(key, val)

#Binary Search Tree
class BST:
    def __init__(self):
        self.root = None
    
    def add_element(self, key, val):
        new_node = Node(key, val)
        
        if (self.root is None):
            self.root = new_node
        
        else:
            #print("not implemented")
            self.root.add_element(key, val)
    
    def __repr__(self):
        return str(self.root.key)
    
    def print(self):
        if (self.root is not None):
            self.root.print()
    
    def pretty_print(self):
        depth = 3
        max_depth = 6
        
        strings = ["" for _ in range(max_depth)]
        
        if (self.root is not None):
            self.root.pretty_print(0, max_depth, strings)
        
        return strings
    
    def find(self, key): #find that return parent
        
    
    def delete(self, key):
        parent, id = self.find()
        
        if (elem.r is None and elem.l is None):
            if (id == "r"):
                parent.r = None
            
            else:
                parent.l = None

        elif (...one descendant...):
            
        
        else: #two children

bst = BST()

#elem_num = 10

#for _ in range(elem_num):
#    bst.add_element(np.random.randint(9), 1)

elems = [6, 5, 8, 9, 4, 7]

for el in elems:
    bst.add_element(el, 1)

strings = bst.pretty_print()

for string in strings:
    print(string)
    print()
# Out:
#                                6
#
#                5                               8
#
#        4                               7               9
